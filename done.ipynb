# %%
import pandas as pd

# %%
df = pd.read_csv('metadata_mp-3.csv')

# %%
# Out:
# array(['/content/drive/MyDrive/Kophos_Features_MVP_34/features_mp/train/9016136408981892-ASK_flip.npy',
#        '/content/drive/MyDrive/Kophos_Features_MVP_34/features_mp/train/6361233197473107-ASK_flip.npy',
#        '/content/drive/MyDrive/Kophos_Features_MVP_34/features_mp/train/5976950094284144-ASK.npy',
#        ...,
#        '/content/drive/MyDrive/Kophos_Features_MVP_34/features_mp/test/01653635897919692-YOU.npy',
#        '/content/drive/MyDrive/Kophos_Features_MVP_34/features_mp/test/5521129539800975-YOU.npy',
#        '/content/drive/MyDrive/Kophos_Features_MVP_34/features_mp/test/9150643832155461-YOU_flip.npy'],
#       shape=(2615,), dtype=object)
