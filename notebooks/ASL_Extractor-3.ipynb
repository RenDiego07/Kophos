# %%
# 1. Mount heavy storage (Google Drive)
from google.colab import drive
import os
import sys
import importlib

if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# 2. Define and validate video directory (APUNTANDO A TU DRIVE)
# Cambia 'ASL_5_Flat_Videos' si le pusiste otro nombre a la carpeta al subirla
VIDEOS_DIR = '/content/drive/MyDrive/ASL_15_Flat_Videos'
# Guardaremos los tensores en Drive para no perderlos si Colab se reinicia
OUTPUT_DIR = '/content/drive/MyDrive/Kophos_Features_MVP_15'

if os.path.exists(VIDEOS_DIR):
    print(f"✅ Videos directory linked successfully: {VIDEOS_DIR}")
else:
    print(f"❌ WARNING: Videos directory not found at {VIDEOS_DIR}. Revisa el nombre en tu Drive.")

os.makedirs(OUTPUT_DIR, exist_ok=True)

# 3. Python 3.12 Patch for Colab's autoreload
sys.modules['imp'] = importlib

# 4. Autoreload extension
# %load_ext autoreload
# %autoreload 2

# 5. Smart GitHub Synchronization
PROJECT_PATH = '/content/Kophos'

if not os.path.exists(PROJECT_PATH):
    print("Cloning the repository for the first time...")
    # !git clone https://github.com/RenDiego07/Kophos.git
else:
    print("Repository exists. Fetching latest commits...")
    # %cd {PROJECT_PATH}
    # !git pull origin main

# 6. Set working directory
# %cd {PROJECT_PATH}
print("\n✅ MLOps Environment is ready.")
# Out:
# ✅ Videos directory linked successfully: /content/drive/MyDrive/ASL_15_Flat_Videos
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Repository exists. Fetching latest commits...
# /content/Kophos
# From https://github.com/RenDiego07/Kophos
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# /content/Kophos
#
# ✅ MLOps Environment is ready.

# %%
print("🚀 Iniciando extracción de MediaPipe...\n")

# !python -u scripts/preprocess.py \
    --nslt_json "data/asl_15_citizen_index.json" \
    --videos_dir "{VIDEOS_DIR}" \
    --output_dir "{OUTPUT_DIR}"
# Out:
# 🚀 Iniciando extracción de MediaPipe...
#
# Inicializando pipeline para ASL Citizen...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#   0% 0/471 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1784435060.813375    3633 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435060.873652    3634 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435060.884804    3634 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435060.885456    3633 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435060.941601    3634 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435060.942339    3633 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435060.950669    3634 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435060.965745    3633 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1784435064.587067    3633 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# 100% 471/471 [33:48<00:00,  4.31s/it]
#
# Proceso completado. Videos procesados: 471, Faltantes: 0

# %%
# 1. Purgar TensorFlow para destruir el conflicto de Protobuf
# !pip uninstall -y tensorflow

# 2. Instalar nuestras librerías
# !pip install mediapipe==0.10.21 opencv-python tqdm --quiet

print("✅ Entorno limpiado y dependencias instaladas sin conflictos.")
# Out:
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Successfully uninstalled tensorflow-2.20.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 56.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 103.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 112.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 MB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 12.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires tensorflow>=2.2.0, which is not installed.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# grain 0.2.18 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# ✅ Entorno limpiado y dependencias instaladas sin conflictos.

# %%
print("🚀 Iniciando el entrenamiento de la BiLSTM (MVP - 5 Clases)...\n")

# Aseguramos las rutas correctas apuntando a tu Drive
FEATURES_DIR = "/content/drive/MyDrive/Kophos_Features_MVP_15"
METADATA_CSV = f"{FEATURES_DIR}/metadata_mp.csv"
RESULTS_DIR = "/content/drive/MyDrive/Kophos_Resultados_MVP"

# Ejecución del entrenamiento
# !python -u scripts/train.py \
    --csv_path "{METADATA_CSV}" \
    --output_dir "{RESULTS_DIR}" \
    --epochs 100 \
    --batch_size 16 \
    --num_classes 5 \
    --lr 0.001
# Out:
# 🚀 Iniciando el entrenamiento de la BiLSTM (MVP - 5 Clases)...
#
# 🚀 Iniciando entrenamiento en: cuda
#
# 📦 Cargando DataLoaders...
# 🧠 Inicializando Modelo BiLSTM para 5 clases...
#
# 🔥 Comenzando Entrenamiento...
#
# --- Epoch 1/100 ---
# Train Loss: 1.6163 | Train Acc: 16.50%
# Val Loss:   1.5977 | Val Acc:   42.86%
# ⭐ Precisión mejoró de 0.00% a 42.86%. Guardando modelo...
#
# --- Epoch 2/100 ---
# Train Loss: 1.5863 | Train Acc: 26.21%
# Val Loss:   1.5563 | Val Acc:   33.33%
#
# --- Epoch 3/100 ---
# Train Loss: 1.4996 | Train Acc: 34.95%
# Val Loss:   1.4631 | Val Acc:   33.33%
#
# --- Epoch 4/100 ---
# Train Loss: 1.3265 | Train Acc: 41.75%
# Val Loss:   1.2402 | Val Acc:   38.10%
#
# --- Epoch 5/100 ---
# Train Loss: 1.1359 | Train Acc: 57.28%
# Val Loss:   1.2330 | Val Acc:   47.62%
# ⭐ Precisión mejoró de 42.86% a 47.62%. Guardando modelo...
#
# --- Epoch 6/100 ---
# Train Loss: 0.9646 | Train Acc: 59.22%
# Val Loss:   1.0495 | Val Acc:   52.38%
# ⭐ Precisión mejoró de 47.62% a 52.38%. Guardando modelo...
#
# --- Epoch 7/100 ---
# Train Loss: 1.0930 | Train Acc: 44.66%
# Val Loss:   0.9396 | Val Acc:   66.67%
# ⭐ Precisión mejoró de 52.38% a 66.67%. Guardando modelo...
#
# --- Epoch 8/100 ---
# Train Loss: 0.9333 | Train Acc: 61.17%
# Val Loss:   0.8769 | Val Acc:   66.67%
#
# --- Epoch 9/100 ---
# Train Loss: 0.8145 | Train Acc: 69.90%
# Val Loss:   0.7362 | Val Acc:   66.67%
#
# --- Epoch 10/100 ---
# Train Loss: 0.7947 | Train Acc: 64.08%
# Val Loss:   0.9048 | Val Acc:   52.38%
#
# --- Epoch 11/100 ---
# Train Loss: 0.7261 | Train Acc: 71.84%
# Val Loss:   0.8803 | Val Acc:   71.43%
# ⭐ Precisión mejoró de 66.67% a 71.43%. Guardando modelo...
#
# --- Epoch 12/100 ---
# Train Loss: 0.7558 | Train Acc: 60.19%
# Val Loss:   0.7835 | Val Acc:   66.67%
#
# --- Epoch 13/100 ---
# Train Loss: 0.7088 | Train Acc: 69.90%
# Val Loss:   0.6187 | Val Acc:   71.43%
#
# --- Epoch 14/100 ---
# Train Loss: 0.5700 | Train Acc: 73.79%
# Val Loss:   0.7007 | Val Acc:   71.43%
#
# --- Epoch 15/100 ---
# Train Loss: 0.5483 | Train Acc: 77.67%
# Val Loss:   0.6997 | Val Acc:   71.43%
#
# --- Epoch 16/100 ---
# Train Loss: 0.4687 | Train Acc: 80.58%
# Val Loss:   0.6121 | Val Acc:   66.67%
#
# --- Epoch 17/100 ---
# Train Loss: 0.4784 | Train Acc: 77.67%
# Val Loss:   0.5045 | Val Acc:   76.19%
# ⭐ Precisión mejoró de 71.43% a 76.19%. Guardando modelo...
#
# --- Epoch 18/100 ---
# Train Loss: 0.3530 | Train Acc: 86.41%
# Val Loss:   0.6374 | Val Acc:   71.43%
#
# --- Epoch 19/100 ---
# Train Loss: 0.3551 | Train Acc: 89.32%
# Val Loss:   0.5261 | Val Acc:   80.95%
# ⭐ Precisión mejoró de 76.19% a 80.95%. Guardando modelo...
#
# --- Epoch 20/100 ---
# Train Loss: 0.3114 | Train Acc: 87.38%
# Val Loss:   0.5626 | Val Acc:   85.71%
# ⭐ Precisión mejoró de 80.95% a 85.71%. Guardando modelo...
#
# --- Epoch 21/100 ---
# Train Loss: 0.2970 | Train Acc: 91.26%
# Val Loss:   0.6391 | Val Acc:   80.95%
#
# --- Epoch 22/100 ---
# Train Loss: 0.3721 | Train Acc: 82.52%
# Val Loss:   0.4468 | Val Acc:   85.71%
#
# --- Epoch 23/100 ---
# Train Loss: 0.2717 | Train Acc: 90.29%
# Val Loss:   0.3821 | Val Acc:   90.48%
# ⭐ Precisión mejoró de 85.71% a 90.48%. Guardando modelo...
#
# --- Epoch 24/100 ---
# Train Loss: 0.5449 | Train Acc: 78.64%
# Val Loss:   0.5047 | Val Acc:   95.24%
# ⭐ Precisión mejoró de 90.48% a 95.24%. Guardando modelo...
#
# --- Epoch 25/100 ---
# Train Loss: 0.3221 | Train Acc: 86.41%
# Val Loss:   0.5034 | Val Acc:   80.95%
#
# --- Epoch 26/100 ---
# Train Loss: 0.2970 | Train Acc: 86.41%
# Val Loss:   0.5215 | Val Acc:   85.71%
#
# --- Epoch 27/100 ---
# Train Loss: 0.2549 | Train Acc: 90.29%
# Val Loss:   0.1880 | Val Acc:   95.24%
#
# --- Epoch 28/100 ---
# Train Loss: 0.2437 | Train Acc: 91.26%
# Val Loss:   0.2905 | Val Acc:   90.48%
#
# --- Epoch 29/100 ---
# Train Loss: 0.1919 | Train Acc: 92.23%
# Val Loss:   0.2014 | Val Acc:   90.48%
#
# --- Epoch 30/100 ---
# Train Loss: 0.2735 | Train Acc: 86.41%
# Val Loss:   0.2001 | Val Acc:   95.24%
#
# --- Epoch 31/100 ---
# Train Loss: 0.2050 | Train Acc: 92.23%
# Val Loss:   0.2304 | Val Acc:   95.24%
#
# --- Epoch 32/100 ---
# Train Loss: 0.1560 | Train Acc: 96.12%
# Val Loss:   0.1271 | Val Acc:   95.24%
#
# --- Epoch 33/100 ---
# Train Loss: 0.1376 | Train Acc: 95.15%
# Val Loss:   0.1933 | Val Acc:   95.24%
#
# --- Epoch 34/100 ---
# Train Loss: 0.1013 | Train Acc: 100.00%
# Val Loss:   0.2709 | Val Acc:   85.71%
#
# --- Epoch 35/100 ---
# Train Loss: 0.1149 | Train Acc: 97.09%
# Val Loss:   0.2705 | Val Acc:   85.71%
#
# --- Epoch 36/100 ---
# Train Loss: 0.1413 | Train Acc: 95.15%
# Val Loss:   0.1155 | Val Acc:   95.24%
#
# --- Epoch 37/100 ---
# Train Loss: 0.1178 | Train Acc: 96.12%
# Val Loss:   0.1782 | Val Acc:   90.48%
#
# --- Epoch 38/100 ---
# Train Loss: 0.1013 | Train Acc: 96.12%
# Val Loss:   0.3331 | Val Acc:   90.48%
#
# --- Epoch 39/100 ---
# Train Loss: 0.1047 | Train Acc: 98.06%
# Val Loss:   0.2104 | Val Acc:   95.24%
#
# --- Epoch 40/100 ---
# Train Loss: 0.2037 | Train Acc: 94.17%
# Val Loss:   0.0359 | Val Acc:   100.00%
# ⭐ Precisión mejoró de 95.24% a 100.00%. Guardando modelo...
#
# --- Epoch 41/100 ---
# Train Loss: 0.1795 | Train Acc: 94.17%
# Val Loss:   0.0546 | Val Acc:   100.00%
#
# --- Epoch 42/100 ---
# Train Loss: 0.1412 | Train Acc: 94.17%
# Val Loss:   0.2938 | Val Acc:   95.24%
#
# --- Epoch 43/100 ---
# Train Loss: 0.1332 | Train Acc: 95.15%
# Val Loss:   0.2437 | Val Acc:   85.71%
#
# --- Epoch 44/100 ---
# Train Loss: 0.1640 | Train Acc: 93.20%
# Val Loss:   0.2309 | Val Acc:   90.48%
#
# --- Epoch 45/100 ---
# Train Loss: 0.2039 | Train Acc: 91.26%
# Val Loss:   0.0456 | Val Acc:   100.00%
#
# --- Epoch 46/100 ---
# Train Loss: 0.0958 | Train Acc: 96.12%
# Val Loss:   0.1849 | Val Acc:   95.24%
#
# --- Epoch 47/100 ---
# Train Loss: 0.0741 | Train Acc: 97.09%
# Val Loss:   0.2709 | Val Acc:   90.48%
#
# --- Epoch 48/100 ---
# Train Loss: 0.0768 | Train Acc: 97.09%
# Val Loss:   0.0478 | Val Acc:   100.00%
#
# --- Epoch 49/100 ---
# Train Loss: 0.0780 | Train Acc: 97.09%
# Val Loss:   0.0516 | Val Acc:   100.00%
#
# --- Epoch 50/100 ---
# Train Loss: 0.0941 | Train Acc: 98.06%
# Val Loss:   0.2106 | Val Acc:   90.48%
#
# --- Epoch 51/100 ---
# Train Loss: 0.2144 | Train Acc: 90.29%
# Val Loss:   0.1312 | Val Acc:   90.48%
#
# --- Epoch 52/100 ---
# Train Loss: 0.2976 | Train Acc: 89.32%
# Val Loss:   0.1163 | Val Acc:   95.24%
#
# --- Epoch 53/100 ---
# Train Loss: 0.1383 | Train Acc: 94.17%
# Val Loss:   0.1442 | Val Acc:   95.24%
#
# --- Epoch 54/100 ---
# Train Loss: 0.0625 | Train Acc: 99.03%
# Val Loss:   0.1639 | Val Acc:   95.24%
#
# --- Epoch 55/100 ---
# Train Loss: 0.0402 | Train Acc: 99.03%
# Val Loss:   0.0506 | Val Acc:   100.00%
#
# --- Epoch 56/100 ---
# Train Loss: 0.0245 | Train Acc: 100.00%
# Val Loss:   0.0968 | Val Acc:   95.24%
#
# --- Epoch 57/100 ---
# Train Loss: 0.0172 | Train Acc: 100.00%
# Val Loss:   0.0738 | Val Acc:   95.24%
#
# --- Epoch 58/100 ---
# Train Loss: 0.0147 | Train Acc: 100.00%
# Val Loss:   0.0998 | Val Acc:   90.48%
#
# --- Epoch 59/100 ---
# Train Loss: 0.0161 | Train Acc: 100.00%
# Val Loss:   0.0737 | Val Acc:   95.24%
#
# --- Epoch 60/100 ---
# Train Loss: 0.0092 | Train Acc: 100.00%
# Val Loss:   0.0705 | Val Acc:   95.24%
#
# --- Epoch 61/100 ---
# Train Loss: 0.0086 | Train Acc: 100.00%
# Val Loss:   0.0837 | Val Acc:   90.48%
#
# --- Epoch 62/100 ---
# Train Loss: 0.0080 | Train Acc: 100.00%
# Val Loss:   0.1003 | Val Acc:   95.24%
#
# --- Epoch 63/100 ---
# Train Loss: 0.0044 | Train Acc: 100.00%
# Val Loss:   0.1001 | Val Acc:   95.24%
#
# --- Epoch 64/100 ---
# Train Loss: 0.0079 | Train Acc: 100.00%
# Val Loss:   0.0837 | Val Acc:   95.24%
#
# --- Epoch 65/100 ---
# Train Loss: 0.0066 | Train Acc: 100.00%
# Val Loss:   0.0673 | Val Acc:   95.24%
#
# --- Epoch 66/100 ---
# Train Loss: 0.0031 | Train Acc: 100.00%
# Val Loss:   0.0563 | Val Acc:   100.00%
#
# --- Epoch 67/100 ---
# Train Loss: 0.0041 | Train Acc: 100.00%
# Val Loss:   0.0535 | Val Acc:   100.00%
#
# --- Epoch 68/100 ---
# Train Loss: 0.0051 | Train Acc: 100.00%
# Val Loss:   0.0428 | Val Acc:   100.00%
#
# --- Epoch 69/100 ---
# Train Loss: 0.0054 | Train Acc: 100.00%
# Val Loss:   0.0446 | Val Acc:   95.24%
#
# --- Epoch 70/100 ---
# Train Loss: 0.0027 | Train Acc: 100.00%
# Val Loss:   0.0503 | Val Acc:   95.24%
#
# --- Epoch 71/100 ---
# Train Loss: 0.0045 | Train Acc: 100.00%
# Val Loss:   0.0537 | Val Acc:   95.24%
#
# --- Epoch 72/100 ---
# Train Loss: 0.0030 | Train Acc: 100.00%
# Val Loss:   0.0554 | Val Acc:   95.24%
#
# --- Epoch 73/100 ---
# Train Loss: 0.0033 | Train Acc: 100.00%
# Val Loss:   0.0598 | Val Acc:   95.24%
#
# --- Epoch 74/100 ---
# Train Loss: 0.0037 | Train Acc: 100.00%
# Val Loss:   0.0664 | Val Acc:   95.24%
#
# --- Epoch 75/100 ---
# Train Loss: 0.0022 | Train Acc: 100.00%
# Val Loss:   0.0702 | Val Acc:   95.24%
#
# --- Epoch 76/100 ---
# Train Loss: 0.0029 | Train Acc: 100.00%
# Val Loss:   0.0701 | Val Acc:   95.24%
#
# --- Epoch 77/100 ---
# Train Loss: 0.0028 | Train Acc: 100.00%
# Val Loss:   0.0704 | Val Acc:   95.24%
#
# --- Epoch 78/100 ---
# Train Loss: 0.0037 | Train Acc: 100.00%
# Val Loss:   0.0710 | Val Acc:   95.24%
#
# --- Epoch 79/100 ---
# Train Loss: 0.0024 | Train Acc: 100.00%
# Val Loss:   0.0871 | Val Acc:   90.48%
#
# --- Epoch 80/100 ---
# Train Loss: 0.0036 | Train Acc: 100.00%
# Val Loss:   0.0887 | Val Acc:   90.48%
#
# --- Epoch 81/100 ---
# Train Loss: 0.0017 | Train Acc: 100.00%
# Val Loss:   0.0713 | Val Acc:   95.24%
#
# --- Epoch 82/100 ---
# Train Loss: 0.0020 | Train Acc: 100.00%
# Val Loss:   0.0684 | Val Acc:   95.24%
#
# --- Epoch 83/100 ---
# Train Loss: 0.0022 | Train Acc: 100.00%
# Val Loss:   0.0833 | Val Acc:   95.24%
#
# --- Epoch 84/100 ---
# Train Loss: 0.0026 | Train Acc: 100.00%
# Val Loss:   0.0808 | Val Acc:   90.48%
#
# --- Epoch 85/100 ---
# Train Loss: 0.0025 | Train Acc: 100.00%
# Val Loss:   0.0784 | Val Acc:   90.48%
#
# --- Epoch 86/100 ---
# Train Loss: 0.0072 | Train Acc: 100.00%
# Val Loss:   0.0671 | Val Acc:   95.24%
#
# --- Epoch 87/100 ---
# Train Loss: 0.0012 | Train Acc: 100.00%
# Val Loss:   0.0809 | Val Acc:   95.24%
#
# --- Epoch 88/100 ---
# Train Loss: 0.0027 | Train Acc: 100.00%
# Val Loss:   0.0714 | Val Acc:   95.24%
#
# --- Epoch 89/100 ---
# Train Loss: 0.0029 | Train Acc: 100.00%
# Val Loss:   0.0754 | Val Acc:   95.24%
#
# --- Epoch 90/100 ---
# Train Loss: 0.0021 | Train Acc: 100.00%
# Val Loss:   0.0949 | Val Acc:   95.24%
#
# --- Epoch 91/100 ---
# Train Loss: 0.0014 | Train Acc: 100.00%
# Val Loss:   0.1011 | Val Acc:   95.24%
#
# --- Epoch 92/100 ---
# Train Loss: 0.0018 | Train Acc: 100.00%
# Val Loss:   0.0964 | Val Acc:   95.24%
#
# --- Epoch 93/100 ---
# Train Loss: 0.0013 | Train Acc: 100.00%
# Val Loss:   0.0837 | Val Acc:   95.24%
#
# --- Epoch 94/100 ---
# Train Loss: 0.0026 | Train Acc: 100.00%
# Val Loss:   0.0698 | Val Acc:   95.24%
#
# --- Epoch 95/100 ---
# Train Loss: 0.0022 | Train Acc: 100.00%
# Val Loss:   0.0658 | Val Acc:   95.24%
#
# --- Epoch 96/100 ---
# Train Loss: 0.0019 | Train Acc: 100.00%
# Val Loss:   0.0641 | Val Acc:   95.24%
#
# --- Epoch 97/100 ---
# Train Loss: 0.0076 | Train Acc: 100.00%
# Val Loss:   0.0636 | Val Acc:   95.24%
#
# --- Epoch 98/100 ---
# Train Loss: 0.0021 | Train Acc: 100.00%
# Val Loss:   0.0612 | Val Acc:   95.24%
#
# --- Epoch 99/100 ---
# Train Loss: 0.0011 | Train Acc: 100.00%
# Val Loss:   0.0593 | Val Acc:   95.24%
#
# --- Epoch 100/100 ---
# Train Loss: 0.0014 | Train Acc: 100.00%
# Val Loss:   0.0578 | Val Acc:   95.24%
#
# 🎉 ¡Entrenamiento Completo! Mejor Accuracy: 100.00%
# 💾 Modelo y logs guardados en: /content/drive/MyDrive/Kophos_Resultados_MVP

# %%
print("🚀 Iniciando el entrenamiento de la BiLSTM (MVP - 5 Clases)...\n")

# Aseguramos las rutas correctas apuntando a tu Drive
FEATURES_DIR = "/content/drive/MyDrive/Kophos_Features_MVP_15"
METADATA_CSV = f"/content/drive/MyDrive/metadata_mp_15.csv"
RESULTS_DIR = "/content/drive/MyDrive/Kophos_Resultados_MVP_15"

# Ejecución del entrenamiento
# !python -u scripts/train.py \
    --csv_path "{METADATA_CSV}" \
    --output_dir "{RESULTS_DIR}" \
    --epochs 100 \
    --batch_size 16 \
    --num_classes 16 \
    --lr 0.001
# Out:
# 🚀 Iniciando el entrenamiento de la BiLSTM (MVP - 5 Clases)...
#
# 🚀 Iniciando entrenamiento en: cuda
#
# 📦 Cargando DataLoaders...
# 🧠 Inicializando Modelo BiLSTM para 16 clases...
#
# 🔥 Comenzando Entrenamiento...
#
# --- Epoch 1/100 ---
# Train Loss: 2.7652 | Train Acc: 7.82%
# Val Loss:   2.7213 | Val Acc:   9.26%
# ⭐ Precisión mejoró de 0.00% a 9.26%. Guardando modelo...
#
# --- Epoch 2/100 ---
# Train Loss: 2.6131 | Train Acc: 12.29%
# Val Loss:   2.4854 | Val Acc:   9.26%
#
# --- Epoch 3/100 ---
# Train Loss: 2.4672 | Train Acc: 12.85%
# Val Loss:   2.3692 | Val Acc:   11.11%
# ⭐ Precisión mejoró de 9.26% a 11.11%. Guardando modelo...
#
# --- Epoch 4/100 ---
# Train Loss: 2.3985 | Train Acc: 10.61%
# Val Loss:   2.3473 | Val Acc:   11.11%
#
# --- Epoch 5/100 ---
# Train Loss: 2.3121 | Train Acc: 13.13%
# Val Loss:   2.2978 | Val Acc:   9.26%
#
# --- Epoch 6/100 ---
# Train Loss: 2.2675 | Train Acc: 15.08%
# Val Loss:   2.2470 | Val Acc:   16.67%
# ⭐ Precisión mejoró de 11.11% a 16.67%. Guardando modelo...
#
# --- Epoch 7/100 ---
# Train Loss: 2.2881 | Train Acc: 15.08%
# Val Loss:   2.2461 | Val Acc:   18.52%
# ⭐ Precisión mejoró de 16.67% a 18.52%. Guardando modelo...
#
# --- Epoch 8/100 ---
# Train Loss: 2.2747 | Train Acc: 13.97%
# Val Loss:   2.3005 | Val Acc:   18.52%
#
# --- Epoch 9/100 ---
# Train Loss: 2.1574 | Train Acc: 19.83%
# Val Loss:   2.2159 | Val Acc:   20.37%
# ⭐ Precisión mejoró de 18.52% a 20.37%. Guardando modelo...
#
# --- Epoch 10/100 ---
# Train Loss: 2.0858 | Train Acc: 22.91%
# Val Loss:   2.1459 | Val Acc:   20.37%
#
# --- Epoch 11/100 ---
# Train Loss: 2.0540 | Train Acc: 23.18%
# Val Loss:   2.0968 | Val Acc:   25.93%
# ⭐ Precisión mejoró de 20.37% a 25.93%. Guardando modelo...
#
# --- Epoch 12/100 ---
# Train Loss: 1.9733 | Train Acc: 25.98%
# Val Loss:   2.0868 | Val Acc:   25.93%
#
# --- Epoch 13/100 ---
# Train Loss: 1.9597 | Train Acc: 27.09%
# Val Loss:   2.0340 | Val Acc:   27.78%
# ⭐ Precisión mejoró de 25.93% a 27.78%. Guardando modelo...
#
# --- Epoch 14/100 ---
# Train Loss: 1.8624 | Train Acc: 26.82%
# Val Loss:   2.0610 | Val Acc:   31.48%
# ⭐ Precisión mejoró de 27.78% a 31.48%. Guardando modelo...
#
# --- Epoch 15/100 ---
# Train Loss: 1.7983 | Train Acc: 31.01%
# Val Loss:   1.8331 | Val Acc:   42.59%
# ⭐ Precisión mejoró de 31.48% a 42.59%. Guardando modelo...
#
# --- Epoch 16/100 ---
# Train Loss: 1.7474 | Train Acc: 34.36%
# Val Loss:   1.8067 | Val Acc:   27.78%
#
# --- Epoch 17/100 ---
# Train Loss: 1.5793 | Train Acc: 38.83%
# Val Loss:   1.5572 | Val Acc:   48.15%
# ⭐ Precisión mejoró de 42.59% a 48.15%. Guardando modelo...
#
# --- Epoch 18/100 ---
# Train Loss: 1.5356 | Train Acc: 37.43%
# Val Loss:   1.8431 | Val Acc:   37.04%
#
# --- Epoch 19/100 ---
# Train Loss: 1.4780 | Train Acc: 43.30%
# Val Loss:   1.4932 | Val Acc:   46.30%
#
# --- Epoch 20/100 ---
# Train Loss: 1.4703 | Train Acc: 43.58%
# Val Loss:   1.5056 | Val Acc:   42.59%
#
# --- Epoch 21/100 ---
# Train Loss: 1.2905 | Train Acc: 48.60%
# Val Loss:   1.3861 | Val Acc:   50.00%
# ⭐ Precisión mejoró de 48.15% a 50.00%. Guardando modelo...
#
# --- Epoch 22/100 ---
# Train Loss: 1.2824 | Train Acc: 47.77%
# Val Loss:   1.6140 | Val Acc:   44.44%
#
# --- Epoch 23/100 ---
# Train Loss: 1.2746 | Train Acc: 47.49%
# Val Loss:   1.4111 | Val Acc:   57.41%
# ⭐ Precisión mejoró de 50.00% a 57.41%. Guardando modelo...
#
# --- Epoch 24/100 ---
# Train Loss: 1.2059 | Train Acc: 50.56%
# Val Loss:   1.2930 | Val Acc:   53.70%
#
# --- Epoch 25/100 ---
# Train Loss: 1.0774 | Train Acc: 57.26%
# Val Loss:   1.4435 | Val Acc:   50.00%
#
# --- Epoch 26/100 ---
# Train Loss: 1.0755 | Train Acc: 54.47%
# Val Loss:   1.4003 | Val Acc:   51.85%
#
# --- Epoch 27/100 ---
# Train Loss: 1.0917 | Train Acc: 53.91%
# Val Loss:   1.3856 | Val Acc:   53.70%
#
# --- Epoch 28/100 ---
# Train Loss: 1.0371 | Train Acc: 60.06%
# Val Loss:   1.2900 | Val Acc:   48.15%
#
# --- Epoch 29/100 ---
# Train Loss: 0.9354 | Train Acc: 62.01%
# Val Loss:   1.5216 | Val Acc:   48.15%
#
# --- Epoch 30/100 ---
# Train Loss: 0.8491 | Train Acc: 66.20%
# Val Loss:   1.1028 | Val Acc:   66.67%
# ⭐ Precisión mejoró de 57.41% a 66.67%. Guardando modelo...
#
# --- Epoch 31/100 ---
# Train Loss: 0.8361 | Train Acc: 64.25%
# Val Loss:   1.2605 | Val Acc:   59.26%
#
# --- Epoch 32/100 ---
# Train Loss: 0.8666 | Train Acc: 64.25%
# Val Loss:   1.1860 | Val Acc:   57.41%
#
# --- Epoch 33/100 ---
# Train Loss: 0.8248 | Train Acc: 67.32%
# Val Loss:   1.4114 | Val Acc:   51.85%
#
# --- Epoch 34/100 ---
# Train Loss: 0.7651 | Train Acc: 69.83%
# Val Loss:   1.1961 | Val Acc:   62.96%
#
# --- Epoch 35/100 ---
# Train Loss: 0.6564 | Train Acc: 73.18%
# Val Loss:   1.6105 | Val Acc:   53.70%
#
# --- Epoch 36/100 ---
# Train Loss: 0.7064 | Train Acc: 71.23%
# Val Loss:   1.1897 | Val Acc:   68.52%
# ⭐ Precisión mejoró de 66.67% a 68.52%. Guardando modelo...
#
# --- Epoch 37/100 ---
# Train Loss: 0.6249 | Train Acc: 76.82%
# Val Loss:   1.0316 | Val Acc:   64.81%
#
# --- Epoch 38/100 ---
# Train Loss: 0.6419 | Train Acc: 73.74%
# Val Loss:   1.3191 | Val Acc:   62.96%
#
# --- Epoch 39/100 ---
# Train Loss: 0.6843 | Train Acc: 71.51%
# Val Loss:   1.1226 | Val Acc:   64.81%
#
# --- Epoch 40/100 ---
# Train Loss: 0.5940 | Train Acc: 79.05%
# Val Loss:   1.4223 | Val Acc:   62.96%
#
# --- Epoch 41/100 ---
# Train Loss: 0.6301 | Train Acc: 77.37%
# Val Loss:   1.1166 | Val Acc:   64.81%
#
# --- Epoch 42/100 ---
# Train Loss: 0.5242 | Train Acc: 80.73%
# Val Loss:   1.1421 | Val Acc:   70.37%
# ⭐ Precisión mejoró de 68.52% a 70.37%. Guardando modelo...
#
# --- Epoch 43/100 ---
# Train Loss: 0.5244 | Train Acc: 78.77%
# Val Loss:   1.0654 | Val Acc:   66.67%
#
# --- Epoch 44/100 ---
# Train Loss: 0.4376 | Train Acc: 84.36%
# Val Loss:   1.0635 | Val Acc:   72.22%
# ⭐ Precisión mejoró de 70.37% a 72.22%. Guardando modelo...
#
# --- Epoch 45/100 ---
# Train Loss: 0.6122 | Train Acc: 78.77%
# Val Loss:   0.9982 | Val Acc:   72.22%
#
# --- Epoch 46/100 ---
# Train Loss: 0.5098 | Train Acc: 80.73%
# Val Loss:   1.0453 | Val Acc:   70.37%
#
# --- Epoch 47/100 ---
# Train Loss: 0.4043 | Train Acc: 85.20%
# Val Loss:   1.1103 | Val Acc:   66.67%
#
# --- Epoch 48/100 ---
# Train Loss: 0.3400 | Train Acc: 88.55%
# Val Loss:   1.0348 | Val Acc:   74.07%
# ⭐ Precisión mejoró de 72.22% a 74.07%. Guardando modelo...
#
# --- Epoch 49/100 ---
# Train Loss: 0.3841 | Train Acc: 84.64%
# Val Loss:   1.2580 | Val Acc:   68.52%
#
# --- Epoch 50/100 ---
# Train Loss: 0.3855 | Train Acc: 87.43%
# Val Loss:   1.2259 | Val Acc:   62.96%
#
# --- Epoch 51/100 ---
# Train Loss: 0.4380 | Train Acc: 84.64%
# Val Loss:   1.2691 | Val Acc:   59.26%
#
# --- Epoch 52/100 ---
# Train Loss: 0.4221 | Train Acc: 81.56%
# Val Loss:   1.2054 | Val Acc:   62.96%
#
# --- Epoch 53/100 ---
# Train Loss: 0.5724 | Train Acc: 79.33%
# Val Loss:   1.7285 | Val Acc:   53.70%
#
# --- Epoch 54/100 ---
# Train Loss: 0.5850 | Train Acc: 78.77%
# Val Loss:   1.5556 | Val Acc:   55.56%
#
# --- Epoch 55/100 ---
# Train Loss: 0.4788 | Train Acc: 84.36%
# Val Loss:   1.1938 | Val Acc:   66.67%
#
# --- Epoch 56/100 ---
# Train Loss: 0.3410 | Train Acc: 87.99%
# Val Loss:   1.1393 | Val Acc:   64.81%
#
# --- Epoch 57/100 ---
# Train Loss: 0.2918 | Train Acc: 89.39%
# Val Loss:   1.3774 | Val Acc:   61.11%
#
# --- Epoch 58/100 ---
# Train Loss: 0.2451 | Train Acc: 91.06%
# Val Loss:   1.0850 | Val Acc:   70.37%
#
# --- Epoch 59/100 ---
# Train Loss: 0.2308 | Train Acc: 91.62%
# Val Loss:   1.2752 | Val Acc:   61.11%
#
# --- Epoch 60/100 ---
# Train Loss: 0.2831 | Train Acc: 91.62%
# Val Loss:   1.3567 | Val Acc:   70.37%
#
# --- Epoch 61/100 ---
# Train Loss: 0.2924 | Train Acc: 91.90%
# Val Loss:   1.3819 | Val Acc:   64.81%
#
# --- Epoch 62/100 ---
# Train Loss: 0.1828 | Train Acc: 94.13%
# Val Loss:   1.4566 | Val Acc:   66.67%
#
# --- Epoch 63/100 ---
# Train Loss: 0.1619 | Train Acc: 95.81%
# Val Loss:   1.4049 | Val Acc:   66.67%
#
# --- Epoch 64/100 ---
# Train Loss: 0.1293 | Train Acc: 96.93%
# Val Loss:   1.1646 | Val Acc:   70.37%
#
# --- Epoch 65/100 ---
# Train Loss: 0.1572 | Train Acc: 94.41%
# Val Loss:   1.3827 | Val Acc:   62.96%
#
# --- Epoch 66/100 ---
# Train Loss: 0.1649 | Train Acc: 94.13%
# Val Loss:   1.3608 | Val Acc:   64.81%
#
# --- Epoch 67/100 ---
# Train Loss: 0.1596 | Train Acc: 94.97%
# Val Loss:   1.6065 | Val Acc:   68.52%
#
# --- Epoch 68/100 ---
# Train Loss: 0.1519 | Train Acc: 95.53%
# Val Loss:   1.3191 | Val Acc:   68.52%
#
# --- Epoch 69/100 ---
# Train Loss: 0.3556 | Train Acc: 90.22%
# Val Loss:   1.9461 | Val Acc:   61.11%
#
# --- Epoch 70/100 ---
# Train Loss: 0.4209 | Train Acc: 84.08%
# Val Loss:   1.4209 | Val Acc:   70.37%
#
# --- Epoch 71/100 ---
# Train Loss: 0.2381 | Train Acc: 91.62%
# Val Loss:   1.5142 | Val Acc:   72.22%
#
# --- Epoch 72/100 ---
# Train Loss: 0.1907 | Train Acc: 94.13%
# Val Loss:   1.4511 | Val Acc:   68.52%
#
# --- Epoch 73/100 ---
# Train Loss: 0.1997 | Train Acc: 93.30%
# Val Loss:   1.3349 | Val Acc:   66.67%
#
# --- Epoch 74/100 ---
# Train Loss: 0.1817 | Train Acc: 94.13%
# Val Loss:   1.4999 | Val Acc:   64.81%
#
# --- Epoch 75/100 ---
# Train Loss: 0.2625 | Train Acc: 92.18%
# Val Loss:   2.2229 | Val Acc:   59.26%
#
# --- Epoch 76/100 ---
# Train Loss: 0.4247 | Train Acc: 87.99%
# Val Loss:   1.3603 | Val Acc:   64.81%
#
# --- Epoch 77/100 ---
# Train Loss: 0.2231 | Train Acc: 94.41%
# Val Loss:   1.1787 | Val Acc:   79.63%
# ⭐ Precisión mejoró de 74.07% a 79.63%. Guardando modelo...
#
# --- Epoch 78/100 ---
# Train Loss: 0.1830 | Train Acc: 94.97%
# Val Loss:   1.4356 | Val Acc:   68.52%
#
# --- Epoch 79/100 ---
# Train Loss: 0.1644 | Train Acc: 95.53%
# Val Loss:   1.3824 | Val Acc:   74.07%
#
# --- Epoch 80/100 ---
# Train Loss: 0.1352 | Train Acc: 96.37%
# Val Loss:   1.4090 | Val Acc:   68.52%
#
# --- Epoch 81/100 ---
# Train Loss: 0.0875 | Train Acc: 98.04%
# Val Loss:   1.2953 | Val Acc:   68.52%
#
# --- Epoch 82/100 ---
# Train Loss: 0.0768 | Train Acc: 97.49%
# Val Loss:   1.2451 | Val Acc:   74.07%
#
# --- Epoch 83/100 ---
# Train Loss: 0.0677 | Train Acc: 98.88%
# Val Loss:   1.1802 | Val Acc:   74.07%
#
# --- Epoch 84/100 ---
# Train Loss: 0.0471 | Train Acc: 99.16%
# Val Loss:   1.3133 | Val Acc:   75.93%
#
# --- Epoch 85/100 ---
# Train Loss: 0.0428 | Train Acc: 99.44%
# Val Loss:   1.4194 | Val Acc:   72.22%
#
# --- Epoch 86/100 ---
# Train Loss: 0.0464 | Train Acc: 99.16%
# Val Loss:   1.5540 | Val Acc:   75.93%
#
# --- Epoch 87/100 ---
# Train Loss: 0.0340 | Train Acc: 99.44%
# Val Loss:   1.4249 | Val Acc:   74.07%
#
# --- Epoch 88/100 ---
# Train Loss: 0.0386 | Train Acc: 99.44%
# Val Loss:   1.5434 | Val Acc:   75.93%
#
# --- Epoch 89/100 ---
# Train Loss: 0.0253 | Train Acc: 99.72%
# Val Loss:   1.4287 | Val Acc:   77.78%
#
# --- Epoch 90/100 ---
# Train Loss: 0.0236 | Train Acc: 100.00%
# Val Loss:   1.4238 | Val Acc:   77.78%
#
# --- Epoch 91/100 ---
# Train Loss: 0.0205 | Train Acc: 100.00%
# Val Loss:   1.5168 | Val Acc:   79.63%
#
# --- Epoch 92/100 ---
# Train Loss: 0.0158 | Train Acc: 100.00%
# Val Loss:   1.4181 | Val Acc:   79.63%
#
# --- Epoch 93/100 ---
# Train Loss: 0.0131 | Train Acc: 100.00%
# Val Loss:   1.3526 | Val Acc:   79.63%
#
# --- Epoch 94/100 ---
# Train Loss: 0.0174 | Train Acc: 100.00%
# Val Loss:   1.4164 | Val Acc:   77.78%
#
# --- Epoch 95/100 ---
# Train Loss: 0.0326 | Train Acc: 98.88%
# Val Loss:   1.4976 | Val Acc:   75.93%
#
# --- Epoch 96/100 ---
# Train Loss: 0.0303 | Train Acc: 99.16%
# Val Loss:   1.5440 | Val Acc:   77.78%
#
# --- Epoch 97/100 ---
# Train Loss: 0.0201 | Train Acc: 100.00%
# Val Loss:   1.4468 | Val Acc:   77.78%
#
# --- Epoch 98/100 ---
# Train Loss: 0.0191 | Train Acc: 99.72%
# Val Loss:   1.6655 | Val Acc:   75.93%
#
# --- Epoch 99/100 ---
# Train Loss: 0.0164 | Train Acc: 99.44%
# Val Loss:   1.4869 | Val Acc:   75.93%
#
# --- Epoch 100/100 ---
# Train Loss: 0.0111 | Train Acc: 100.00%
# Val Loss:   1.3490 | Val Acc:   81.48%
# ⭐ Precisión mejoró de 79.63% a 81.48%. Guardando modelo...
#
# 🎉 ¡Entrenamiento Completo! Mejor Accuracy: 81.48%
# 💾 Modelo y logs guardados en: /content/drive/MyDrive/Kophos_Resultados_MVP_15

# %%
######################################### Separación de videos

# %%
import zipfile
import pandas as pd
from collections import Counter
import os

zip_path = "/content/drive/MyDrive/ASL_Citizen.zip"
csv_salida = "/content/conteo_palabras_asl_citizen.csv"

print("Analizando el archivo ZIP en memoria (sin extraer videos)...")

try:
    with zipfile.ZipFile(zip_path, 'r') as z:
        archivos = z.namelist()

        # 1. Filtrar solo los archivos de video
        videos = [f for f in archivos if f.endswith('.mp4')]
        print(f"Total de videos encontrados: {len(videos)}")

        # 2. Extraer la palabra de cada nombre de archivo
        palabras = []
        for v in videos:
            # Aislar el nombre del archivo (ej: 5086723486875651-RUN.mp4)
            nombre_archivo = os.path.basename(v)

            # Cortar por el guion '-' y quitar la extensión '.mp4'
            if '-' in nombre_archivo:
                palabra = nombre_archivo.split('-')[-1].replace('.mp4', '')
                palabras.append(palabra)

        # 3. Contar cuántos videos hay por cada palabra
        print("Contando frecuencias...")
        conteo = Counter(palabras)

        # 4. Convertir a DataFrame de Pandas y ordenar
        df_conteo = pd.DataFrame(conteo.items(), columns=['Palabra', 'Cantidad_Videos'])
        df_conteo = df_conteo.sort_values(by='Cantidad_Videos', ascending=False)

        # 5. Exportar a CSV
        df_conteo.to_csv(csv_salida, index=False)

        print(f"\n¡Análisis completado! Se encontraron {len(df_conteo)} palabras únicas.")
        print("\n--- Top 5 palabras con más videos ---")
        print(df_conteo.head(5).to_string(index=False))
        print(f"\n✅ El archivo CSV se ha guardado en: {csv_salida}")
        print("Ya puedes descargarlo desde el panel izquierdo de Colab y abrirlo en tu Excel/Numbers.")

except FileNotFoundError:
    print("Error: No se encontró el archivo ZIP. Verifica la ruta.")
# Out:
# Analizando el archivo ZIP en memoria (sin extraer videos)...
# Total de videos encontrados: 83399
# Contando frecuencias...
#
# ¡Análisis completado! Se encontraron 5382 palabras únicas.
#
# --- Top 5 palabras con más videos ---
#    Palabra  Cantidad_Videos
#         CA              120
#         UP               60
#     TRIP 2               52
#        DOG               44
# BASKETBALL               43
#
# ✅ El archivo CSV se ha guardado en: /content/conteo_palabras_asl_citizen.csv
# Ya puedes descargarlo desde el panel izquierdo de Colab y abrirlo en tu Excel/Numbers.

# %%
import zipfile
import os
import shutil
from collections import defaultdict

# 1. Definir rutas y objetivo
zip_path = "/content/drive/MyDrive/ASL_Citizen.zip"
extract_path = "/content/Mis_13_Clases"
zip_descarga = "/content/Mis_13_Clases_Descarga"

palabras_objetivo = {
    "NEED", "TRIP", "HOSPITAL", "DEAF", "BREAKFAST",
    "EAT", "MOVIE", "COOL", "PARTY", "NIGHT",
    "ME", "LAUGH", "MAKE"
}

os.makedirs(extract_path, exist_ok=True)
conteo_extraido = defaultdict(int)

print(f"Buscando {len(palabras_objetivo)} clases en la memoria. Esto tomará unos segundos...")

try:
    with zipfile.ZipFile(zip_path, 'r') as z:
        archivos = z.namelist()

        # Filtrar los videos que nos interesan
        videos_a_extraer = []
        for f in archivos:
            if f.endswith('.mp4'):
                # Extraer la palabra del formato "123456789-PALABRA.mp4"
                nombre_base = os.path.basename(f)
                if '-' in nombre_base:
                    palabra = nombre_base.split('-')[-1].replace('.mp4', '')
                    if palabra in palabras_objetivo:
                        videos_a_extraer.append((f, palabra))

        print(f"Se encontraron {len(videos_a_extraer)} videos en total que coinciden con tus clases.")
        print("Iniciando extracción al disco de Colab...")

        # Extraer y contar
        for ruta_original, palabra in videos_a_extraer:
            z.extract(ruta_original, extract_path)
            conteo_extraido[palabra] += 1

    print("\n--- Resumen de Extracción ---")
    for palabra, cantidad in sorted(conteo_extraido.items(), key=lambda x: x[1], reverse=True):
        print(f"{palabra}: {cantidad} videos")

    print("\nComprimiendo la carpeta resultante para descarga...")
    shutil.make_archive(zip_descarga, 'zip', extract_path)

    print(f"\n✅ ¡Éxito! El archivo listo para descargar a tu Mac es: {zip_descarga}.zip")

except FileNotFoundError:
    print("Error: No se encontró el archivo ZIP. Verifica que tu Drive esté montado correctamente.")
# Out:
# Buscando 13 clases en la memoria. Esto tomará unos segundos...
# Se encontraron 455 videos en total que coinciden con tus clases.
# Iniciando extracción al disco de Colab...
#
# --- Resumen de Extracción ---
# TRIP: 39 videos
# MOVIE: 38 videos
# DEAF: 38 videos
# HOSPITAL: 38 videos
# NIGHT: 38 videos
# PARTY: 38 videos
# BREAKFAST: 38 videos
# EAT: 38 videos
# LAUGH: 31 videos
# ME: 30 videos
# COOL: 30 videos
# MAKE: 30 videos
# NEED: 29 videos
#
# Comprimiendo la carpeta resultante para descarga...
#
# ✅ ¡Éxito! El archivo listo para descargar a tu Mac es: /content/Mis_13_Clases_Descarga.zip

# %%
import zipfile
import os
import shutil
from collections import defaultdict

# 1. Definir rutas y objetivo
zip_path = "/content/drive/MyDrive/ASL_Citizen.zip"
extract_path = "/content/Mis_26_Clases"
zip_descarga = "/content/Mis_26_Clases_Descarga"

# 2. Definir el léxico completo (26 palabras)
palabras_objetivo = {
    # Base (5)
    "HOSPITAL", "LAUGH", "MAKE", "ME", "NEED",
    # Control (5)
    "START", "STOP", "CANCEL", "WAIT", "HELP",
    # Consulta (5)
    "FIND", "SHOW", "TELL", "ASK", "ANSWER",
    # Feedback (5)
    "UNDERSTAND", "KNOW", "WANT", "LIKE", "THINK",
    # Interfaz (5)
    "OPEN", "CLOSE", "READ", "WRITE", "CHAT",
    # Adicional (1)
    "TO"
}

os.makedirs(extract_path, exist_ok=True)
conteo_extraido = defaultdict(int)

print(f"Buscando {len(palabras_objetivo)} clases en la memoria. Esto tomará unos segundos...")

try:
    with zipfile.ZipFile(zip_path, 'r') as z:
        archivos = z.namelist()

        # Filtrar los videos que nos interesan
        videos_a_extraer = []
        for f in archivos:
            if f.endswith('.mp4'):
                # Extraer la palabra del formato "123456789-PALABRA.mp4"
                nombre_base = os.path.basename(f)
                if '-' in nombre_base:
                    palabra = nombre_base.split('-')[-1].replace('.mp4', '')
                    if palabra in palabras_objetivo:
                        videos_a_extraer.append((f, palabra))

        print(f"Se encontraron {len(videos_a_extraer)} videos en total que coinciden con tus clases.")
        print("Iniciando extracción al disco de Colab...")

        # Extraer y contar
        for ruta_original, palabra in videos_a_extraer:
            z.extract(ruta_original, extract_path)
            conteo_extraido[palabra] += 1

    print("\n--- Resumen de Extracción ---")
    for palabra, cantidad in sorted(conteo_extraido.items(), key=lambda x: x[1], reverse=True):
        print(f"{palabra}: {cantidad} videos")

    print("\nComprimiendo la carpeta resultante para descarga...")
    shutil.make_archive(zip_descarga, 'zip', extract_path)

    print(f"\n✅ ¡Éxito! El archivo listo para descargar es: {zip_descarga}.zip")

except FileNotFoundError:
    print("Error: No se encontró el archivo ZIP. Verifica que tu Drive esté montado correctamente.")
# Out:
# Buscando 26 clases en la memoria. Esto tomará unos segundos...
# Se encontraron 788 videos en total que coinciden con tus clases.
# Iniciando extracción al disco de Colab...
#
# --- Resumen de Extracción ---
# HOSPITAL: 38 videos
# CANCEL: 36 videos
# CLOSE: 31 videos
# LAUGH: 31 videos
# UNDERSTAND: 31 videos
# ME: 30 videos
# THINK: 30 videos
# READ: 30 videos
# HELP: 30 videos
# CHAT: 30 videos
# ANSWER: 30 videos
# FIND: 30 videos
# KNOW: 30 videos
# STOP: 30 videos
# WRITE: 30 videos
# MAKE: 30 videos
# ASK: 30 videos
# OPEN: 30 videos
# WANT: 29 videos
# NEED: 29 videos
# SHOW: 29 videos
# LIKE: 29 videos
# START: 29 videos
# WAIT: 29 videos
# TELL: 29 videos
# TO: 28 videos
#
# Comprimiendo la carpeta resultante para descarga...
#
# ✅ ¡Éxito! El archivo listo para descargar es: /content/Mis_26_Clases_Descarga.zip

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_402/1201304083.py in <cell line: 0>()
#       3 # 1. Cargamos el CSV forzando que todas las columnas sean texto (evita el error de numpy)
#       4 ruta_csv = "/content/metadata_mp.csv"
# ----> 5 df = pd.read_csv(ruta_csv, dtype=str)
#       6
#       7 # 2. Extraemos la palabra directamente del video_id (asegurándonos de que x sea string)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1966                 new_col_dict = col_dict
#    1967
# -> 1968             df = DataFrame(
#    1969                 new_col_dict,
#    1970                 columns=columns,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     441         from pandas.core.series import Series
#     442
# --> 443         arrays = Series(data, index=columns, dtype=object)
#     444         missing = arrays.isna()
#     445         if index is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     488
#     489         if index is not None:
# --> 490             index = ensure_index(index)
#     491
#     492         if dtype is not None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    7645             return MultiIndex.from_arrays(index_like)
#    7646         else:
# -> 7647             return Index(index_like, copy=copy, tupleize_cols=False)
#    7648     else:
#    7649         return Index(index_like, copy=copy)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols)
#     563
#     564         try:
# --> 565             arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     566         except ValueError as err:
#     567             if "index must be specified when data is not list-like" in str(err):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     652
#     653         else:
# --> 654             subarr = maybe_convert_platform(data)
#     655             if subarr.dtype == object:
#     656                 subarr = cast(np.ndarray, subarr)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/cast.py in maybe_convert_platform(values)
#     137     if arr.dtype == _dtype_obj:
#     138         arr = cast(np.ndarray, arr)
# --> 139         arr = lib.maybe_convert_objects(arr)
#     140
#     141     return arr
#
# lib.pyx in pandas._libs.lib.maybe_convert_objects()
#
# TypeError: Cannot convert numpy.ndarray to numpy.ndarray
